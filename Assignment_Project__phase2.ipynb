# %% [markdown]
# # Project: Text Analytics (Knowledge base Design and Implementation)
# # Team - TalkTech Tinkerers
#
# ### Members:
# ### Rodgers Okeyo Ochieng
# ### Jihee Wang
# ### Divyanshi Singh
# ### Chandan Patel

# %% [markdown]
# ![plan.png](plan.png)

# %% [markdown]
# ### In this Notebook we perform the below task:
#
# **Data Collection:**
# Load all the collected data or files Collected files.
#
# **Data Preprocessing**
# Preprocess the data as required for schema.
#
# **Vectorization**
# Convert the preprocessed text data into vectors using the selected vectorization techniques.
#
# **Database Implementation**
# Use Pinecone to create a vector database and store the vectors along with associated metadata.
#
# **Database Testing**
# Implement a few test prompts to verify the efficacy of the database in improving query responses.

# %% [markdown]
# ### Import Necessary key and Libraries

# %%
import os
import openai
import sys
sys.path.append('../..')

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file

openai.api_key  = os.environ['OPENAI_API_KEY']

# %%
from langchain.chains import RetrievalQA  ## retrieval over some documents
from langchain.chat_models import ChatOpenAI
from langchain.document_loaders import CSVLoader  ## document loader
from langchain.document_loaders import PyPDFLoader
from IPython.display import display, Markdown
from langchain.prompts import PromptTemplate
import pinecone # pip3 install "pinecone-client[grpc]"
from langchain.vectorstores import Pinecone
from langchain.chat_models import ChatOpenAI

from pprint import pprint # pretty print

# %% [markdown]
# ## Data Collected through various sources and Loading these documents

# %% [markdown]
# ![Documents.PNG](Documents.PNG)

# %%
from langchain.document_loaders import PyPDFLoader

# Load PDF
loaders = [
    # Duplicate documents on purpose - messy data
    PyPDFLoader("./data1/doc1_ overall admission process of MS BAIS_with specific 8 steps.pdf"),
    PyPDFLoader("./data1/doc2_how to apply for MS BAIS_apply in 6 easy steps (application, fee, transcript, test score, additional infromation, clearance questions).pdf"),
    PyPDFLoader("./data1/doc3_MS BAIS Admission requirements (application, four_year bachelor degree, gmat or gre,relevant work experience, recommendations,  toefl, sop).pdf"),
    PyPDFLoader("./data1/doc4_cost of MS BAIS course (tuition fee, online tuition caculator,  our_of_state tuition).pdf"),
    PyPDFLoader("./data1/doc5_contact admissions.pdf"),
    PyPDFLoader("./data1/doc6_MS BAIS application deadlines (spring application deadline, fall appilcation deadline).pdf"),
    PyPDFLoader("./data1/doc7_explore graduate programs (types , graduate catalog, graduate research, concurrent, accelerated bachelors to masters degree, online programs).pdf"),
    PyPDFLoader("./data1/doc8_what is I20 (full name, issued by, purpose, usage, important features, validity, importance).pdf"),
    PyPDFLoader("./data1/doc9_most frequently asked questions (admission, application, program, finances, international students).pdf"),
    PyPDFLoader("./data1/doc10_additional information (cost of attendance cost, assistantships, ways to save, office of financial aid, scholarships, fellowship, onoff campus jobs).pdf"),
    PyPDFLoader("./data1/doc11_graduate assistantships.pdf"),
    PyPDFLoader("./data1/doc12_MS BAIS Curriculum (required time, coursework, necessary prerequisite, credit hours, core courses, capstone, concentrations).pdf"),
    PyPDFLoader("./data1/doc13_MS BAIS curriculum requirements (minimum, incoming students, prerequisites, executive weekend, core, capstone, concentration, electives).pdf"),
    PyPDFLoader("./data1/doc14_MS BAIS prerequisites courses for incoming students.pdf"),
    PyPDFLoader("./data1/doc15_global executive program (full time, 100 per online).pdf"),
    PyPDFLoader("./data1/doc16_getting started with MS BAIS_new student checklist.pdf"),
    PyPDFLoader("./data1/doc17_Conversation Records between Students and College Management.pdf"),
]
docs = []
for loader in loaders:
    docs.extend(loader.load())

# %%
## check docs
docs[0].page_content[0:500]
# Out:
# '1. Overall Admission Process  of MS BAIS  \nWe get thousands of applications, which are reviewed first by our Office of Graduate \nAdmissions and then by our MS -BAIS program on a first come, first served basis. The entire \nprocess may take us up to two months, and admissions will close whenever we reach our \nintake capacity for the academic year. Please contact us if you don’t hear back from us in \ntwo months. Our admissions process is as follows:  \n \nStep1. Submit your application, complete with'

# %% [markdown]
# #### metadata information of the loaded docs below

# %%
# Iterate through the list of documents and collect metadata
all_metadata = []

for doc in docs:
    metadata = doc.metadata
    all_metadata.append(metadata)

# Print all metadata at the end
for metadata in all_metadata:
    print(metadata)
# Out:
# {'source': './data1/doc1_ overall admission process of MS BAIS_with specific 8 steps.pdf', 'page': 0}
# {'source': './data1/doc2_how to apply for MS BAIS_apply in 6 easy steps (application, fee, transcript, test score, additional infromation, clearance questions).pdf', 'page': 0}
# {'source': './data1/doc2_how to apply for MS BAIS_apply in 6 easy steps (application, fee, transcript, test score, additional infromation, clearance questions).pdf', 'page': 1}
# {'source': './data1/doc2_how to apply for MS BAIS_apply in 6 easy steps (application, fee, transcript, test score, additional infromation, clearance questions).pdf', 'page': 2}
# {'source': './data1/doc3_MS BAIS Admission requirements (application, four_year bachelor degree, gmat or gre,relevant work experience, recommendations,  toefl, sop).pdf', 'page': 0}
# {'source': './data1/doc3_MS BAIS Admission requirements (application, four_year bachelor degree, gmat or gre,relevant work experience, recommendations,  toefl, sop).pdf', 'page': 1}
# {'source': './data1/doc4_cost of MS BAIS course (tuition fee, online tuition caculator,  our_of_state tuition).pdf', 'page': 0}
# {'source': './data1/doc5_contact admissions.pdf', 'page': 0}
# {'source': './data1/doc6_MS BAIS application deadlines (spring application deadline, fall appilcation deadline).pdf', 'page': 0}
# {'source': './data1/doc7_explore graduate programs (types , graduate catalog, graduate research, concurrent, accelerated bachelors to masters degree, online programs).pdf', 'page': 0}
# {'source': './data1/doc7_explore graduate programs (types , graduate catalog, graduate research, concurrent, accelerated bachelors to masters degree, online programs).pdf', 'page': 1}
# {'source': './data1/doc7_explore graduate programs (types , graduate catalog, graduate research, concurrent, accelerated bachelors to masters degree, online programs).pdf', 'page': 2}
# {'source': './data1/doc8_what is I20 (full name, issued by, purpose, usage, important features, validity, importance).pdf', 'page': 0}
# {'source': './data1/doc8_what is I20 (full name, issued by, purpose, usage, important features, validity, importance).pdf', 'page': 1}
# {'source': './data1/doc9_most frequently asked questions (admission, application, program, finances, international students).pdf', 'page': 0}
# {'source': './data1/doc9_most frequently asked questions (admission, application, program, finances, international students).pdf', 'page': 1}
# {'source': './data1/doc9_most frequently asked questions (admission, application, program, finances, international students).pdf', 'page': 2}
# {'source': './data1/doc9_most frequently asked questions (admission, application, program, finances, international students).pdf', 'page': 3}
# {'source': './data1/doc10_additional information (cost of attendance cost, assistantships, ways to save, office of financial aid, scholarships, fellowship, onoff campus jobs).pdf', 'page': 0}
# {'source': './data1/doc10_additional information (cost of attendance cost, assistantships, ways to save, office of financial aid, scholarships, fellowship, onoff campus jobs).pdf', 'page': 1}
# {'source': './data1/doc10_additional information (cost of attendance cost, assistantships, ways to save, office of financial aid, scholarships, fellowship, onoff campus jobs).pdf', 'page': 2}
# {'source': './data1/doc11_graduate assistantships.pdf', 'page': 0}
# {'source': './data1/doc12_MS BAIS Curriculum (required time, coursework, necessary prerequisite, credit hours, core courses, capstone, concentrations).pdf', 'page': 0}
# {'source': './data1/doc13_MS BAIS curriculum requirements (minimum, incoming students, prerequisites, executive weekend, core, capstone, concentration, electives).pdf', 'page': 0}
# {'source': './data1/doc13_MS BAIS curriculum requirements (minimum, incoming students, prerequisites, executive weekend, core, capstone, concentration, electives).pdf', 'page': 1}
# {'source': './data1/doc13_MS BAIS curriculum requirements (minimum, incoming students, prerequisites, executive weekend, core, capstone, concentration, electives).pdf', 'page': 2}
# {'source': './data1/doc13_MS BAIS curriculum requirements (minimum, incoming students, prerequisites, executive weekend, core, capstone, concentration, electives).pdf', 'page': 3}
# {'source': './data1/doc14_MS BAIS prerequisites courses for incoming students.pdf', 'page': 0}
# {'source': './data1/doc14_MS BAIS prerequisites courses for incoming students.pdf', 'page': 1}
# {'source': './data1/doc14_MS BAIS prerequisites courses for incoming students.pdf', 'page': 2}
# {'source': './data1/doc15_global executive program (full time, 100 per online).pdf', 'page': 0}
# {'source': './data1/doc15_global executive program (full time, 100 per online).pdf', 'page': 1}
# {'source': './data1/doc16_getting started with MS BAIS_new student checklist.pdf', 'page': 0}
# {'source': './data1/doc16_getting started with MS BAIS_new student checklist.pdf', 'page': 1}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 0}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 1}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 2}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 3}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 5}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 6}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 7}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 8}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 9}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 10}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 11}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 12}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 13}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 14}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 15}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 16}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 17}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 18}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 19}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 20}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 21}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 22}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 23}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 24}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 25}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 26}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 27}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 28}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 29}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 30}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 31}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 32}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 33}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 34}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 35}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 36}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 37}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 38}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 39}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 40}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 41}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 42}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 43}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 44}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 45}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 46}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 47}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 48}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 49}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 50}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 51}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 52}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 53}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 54}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 55}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 56}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 57}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 58}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 59}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 60}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 61}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 62}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 63}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 64}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 65}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 66}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 67}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 68}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 69}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 70}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 71}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 72}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 73}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 74}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 75}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 76}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 77}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 78}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 79}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 80}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 81}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 82}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 83}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 84}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 85}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 86}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 87}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 88}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 89}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 90}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 91}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 92}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 93}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 94}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 95}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 96}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 97}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 98}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 99}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 100}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 101}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 102}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 103}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 104}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 105}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 106}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 107}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 108}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 109}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 110}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 111}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 112}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 113}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 114}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 115}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 116}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 117}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 118}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 119}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 120}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 121}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 122}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 123}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 124}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 125}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 126}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 127}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 128}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 129}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 130}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 131}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 132}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 133}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 134}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 135}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 136}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 137}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 138}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 139}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 140}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 141}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 142}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 143}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 144}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 145}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 146}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 147}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 148}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 149}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 150}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 151}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 152}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 153}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 154}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 155}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 156}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 157}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 158}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 159}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 160}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 161}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 162}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 163}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 164}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 165}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 166}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 167}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 168}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 169}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 170}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 171}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 172}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 173}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 174}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 175}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 176}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 177}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 178}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 179}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 180}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 181}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 182}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 183}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 184}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 185}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 186}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 187}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 188}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 189}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 190}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 191}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 192}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 193}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 194}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 195}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 196}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 197}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 198}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 199}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 200}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 201}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 202}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 203}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 204}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 205}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 206}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 207}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 208}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 209}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 210}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 211}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 212}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 213}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 214}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 215}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 216}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 217}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 218}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 219}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 220}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 221}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 222}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 223}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 224}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 225}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 226}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 227}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 228}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 229}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 230}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 231}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 232}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 233}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 234}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 235}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 236}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 237}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 238}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 239}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 240}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 241}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 242}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 243}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 244}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 245}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 246}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 247}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 248}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 249}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 250}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 251}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 252}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 253}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 254}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 255}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 256}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 257}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 258}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 259}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 260}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 261}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 262}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 263}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 264}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 265}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 266}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 267}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 268}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 269}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 270}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 271}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 272}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 273}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 274}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 275}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 276}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 277}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 278}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 279}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 280}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 281}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 282}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 283}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 284}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 285}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 286}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 287}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 288}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 289}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 290}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 291}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 292}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 293}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 294}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 295}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 296}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 297}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 298}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 299}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 300}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 301}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 302}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 303}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 304}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 305}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 306}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 307}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 308}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 309}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 310}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 311}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 312}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 313}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 314}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 315}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 316}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 317}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 318}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 319}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 320}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 321}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 322}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 323}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 324}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 325}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 326}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 327}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 328}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 329}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 330}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 331}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 332}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 333}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 334}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 335}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 336}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 337}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 338}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 339}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 340}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 341}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 342}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 343}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 344}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 345}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 346}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 347}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 348}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 349}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 350}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 351}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 352}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 353}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 354}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 355}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 356}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 357}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 358}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 359}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 360}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 361}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 362}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 363}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 364}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 365}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 366}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 367}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 368}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 369}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 370}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 371}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 372}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 373}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 374}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 375}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 376}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 377}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 378}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 379}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 380}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 381}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 382}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 383}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 384}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 385}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 386}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 387}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 388}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 389}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 390}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 391}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 392}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 393}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 394}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 395}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 396}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 397}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 398}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 399}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 400}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 401}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 402}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 403}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 404}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 405}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 406}
# ...
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4155}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4156}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4157}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4158}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4159}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4160}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4161}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4162}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4163}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4164}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4165}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4166}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4167}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4168}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4169}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4170}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4171}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4172}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4173}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4174}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4175}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4176}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4177}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4178}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4179}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4180}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4181}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4182}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4183}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4184}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4185}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4186}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4187}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4188}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4189}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4190}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4191}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4192}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4193}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4194}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4195}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4196}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4197}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4198}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4199}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4200}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4201}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4202}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4203}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4204}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4205}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4206}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4207}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4208}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4209}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4210}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4211}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4212}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4213}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4214}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4215}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4216}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4217}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4218}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4219}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4220}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4221}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4222}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4223}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4224}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4225}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4226}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4227}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4228}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4229}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4230}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4231}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4232}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4233}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4234}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4235}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4236}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4237}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4238}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4239}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4240}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4241}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4242}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4243}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4244}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4245}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4246}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4247}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4248}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4249}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4250}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4251}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4252}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4253}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4254}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4255}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4256}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4257}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4258}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4259}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4260}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4261}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4262}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4263}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4264}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4265}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4266}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4267}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4268}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4269}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4270}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4271}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4272}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4273}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4274}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4275}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4276}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4277}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4278}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4279}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4280}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4281}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4282}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4283}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4284}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4285}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4286}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4287}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4288}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4289}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4290}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4291}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4292}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4293}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4294}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4295}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4296}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4297}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4298}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4299}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4300}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4301}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4302}
# {'source': './data1/doc17_Conversation Records between Students and College Management.pdf', 'page': 4303}

# %% [markdown]
# ## Data Preprocessing
#
# Here will do necessary splitting into chunks and embedding

# %% [markdown]
# ### Document Splitting into chunks
#
# Document spiltted into chunks so that predefined doc size can be retrived.

# %%
# Split
from langchain.text_splitter import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 1000,
    chunk_overlap = 20
)

# %%
texts = text_splitter.split_documents(docs)

# %%
## check text length
len(texts)
# Out:
# 10852

# %%
## check first doc
texts[1]
# Out:
# Document(page_content='some additional supplemental information via an online form. Note: If you did not receive this e -mail, your \napplication is likely still pending at our G raduate Admissions Office. Contact them at 813 -974-3350 \nor GradAdmissions@usf.edu  (and not the MS -BAIS program director) for status on your application.  \nStep4. The MS -BAIS prog ram will review your complete application and notify you the final decision on your \napplication. Expect this process to take another month.  \nStep5. If you are an international student, you will then have to provide proof of funds for our Office of \nInternati onal Students to issue you an I -20. This may require a bank statement or a bank loan. Domestic students \nmay skip to Step 7.  \nStep6. Upon receiving your I -20, schedule a visa appointment at your closest US consulate or embassy. \nDepending on applicant volume,  it may take months to get a visa appointment. If you don’t get your visa', metadata={'source': './data1/doc1_ overall admission process of MS BAIS_with specific 8 steps.pdf', 'page': 0})

# %% [markdown]
# ![split.png](split.png)

# %% [markdown]
# Above is the explanation of the splitting and embedding

# %% [markdown]
# ## Vectorization

# %% [markdown]
# ## Embeddings
#
# Let's take our splits and embed them using text embedding ada

# %%
from langchain.embeddings.openai import OpenAIEmbeddings
embeddings = OpenAIEmbeddings(deployment="text-embedding-ada-002")

# %% [markdown]
# ## Vectorstores and Storage using Pinecone
# Applications that involve large language models, generative AI, and semantic search rely on vector embeddings, a type of data that represents semantic information. This information allows AI applications to gain understanding and maintain a long-term memory that they can draw upon when executing complex tasks.

# %% [markdown]
# ## Integrate a Knowledge Base using Pinecone and LangChain
#
# We will use Pinecone to create a vector database. We will use the LangChain to create a knowledge base. The knowledge base will be used to answer questions.

# %%
# Import and initialize Pinecone client
pinecone.init(
    api_key=os.getenv('PINECONE_API_KEY'),  
    environment=os.getenv('PINECONE_ENV')  
)

# %% [markdown]
# ## Pinecone Database Implementation

# %%
# create an index

pinecone.init(api_key=os.getenv('PINECONE_API_KEY'), environment=os.getenv('PINECONE_ENV'))

# pinecone.delete_index("langchain-demo-index")

# pinecone.create_index("langchain-demo-index", dimension=1536) # 1536 is openai ada embedding dimension

# %%
# Upload vectors to Pinecone
# You need first create an index in Pinecone, see www.pinecone.io - set it to 1536 dimensions

index_name = "langchain-demo-index"
vectordb = Pinecone.from_documents(texts, embeddings, index_name=index_name) # load all text chunks into Pinecone with the associated embeddings
# Out:
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-9E0KtZHRQjJeAMkp7vbAlMhP on tokens per min. Limit: 1000000 / min. Current: 842688 / min. Contact us through our help center at help.openai.com if you continue to have issues..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-9E0KtZHRQjJeAMkp7vbAlMhP on tokens per min. Limit: 1000000 / min. Current: 769844 / min. Contact us through our help center at help.openai.com if you continue to have issues..

# %% [markdown]
# ## Database Testing
# Database testing can be done by retrieving the chunks through similarity search. There can be various other methods as well where we can retrieve the files related to the search text. Below shown are the example using database testing using similarty search retrieval and langChain Retrieval QA.

# %% [markdown]
# ### Retrieval of Docs
#
# Retrieval of docs from the vector database which are the closest match from the query

# %%
# Do a simple vector similarity search

query = "Tell me admission process in BAIS"
result = vectordb.similarity_search(query)

pprint(result)
# Out:
# [Document(page_content='1. Overall Admission Process  of MS BAIS  \nWe get thousands of applications, which are reviewed first by our Office of Graduate \nAdmissions and then by our MS -BAIS program on a first come, first served basis. The entire \nprocess may take us up to two months, and admissions will close whenever we reach our \nintake capacity for the academic year. Please contact us if you don’t hear back from us in \ntwo months. Our admissions process is as follows:  \n \nStep1. Submit your application, complete with GRE/GMAT scores, college transcripts, and other necessary details \nto USF Office of Graduate Admissions.  \nStep2. The graduate admissions offi ce will notify you the receipt of your application, assign you a U number, \nreview your application, and if complete, will refer your application to the MS -BAIS program. This process takes \none month.  \nStep3. The MS -BAIS program will notify you by e -mail our receipt of your application and ask you to provide us', metadata={'page': 0.0, 'source': './data1/doc1_ overall admission process of MS BAIS_with specific 8 steps.pdf'}),
#  Document(page_content='om%2Fwatch%3Fv%3DC0cQFyqk4eM%26t%3D3s&data=05%7C01%7Cmsbais-admissions%40us\nf.edu%7C30ad7d4e6c494f884c5508db1fe44fe0%7C741bf7dee2e546df8d6782607df9deaa%7C0%\n7C0%7C638138838832678219%7CUnknown%7CTWFpbGZsb3d8eyJWIjoiMC4wLjAwMDAiLCJQIj\noiV2luMzIiLCJBTiI6Ik1haWwiLCJXVCI6Mn0%3D%7C2000%7C%7C%7C&sdata=U%2FhqEMMsA\n%2F22g%2B%2BKrgVoFuKYAGHURMYgSSuyh7CpoGc%3D&reserved=0]! We have\nrecommended that you be admitted to the MS BAIS program for Fall 2023. You will receive an\nofficial acceptance once the Graduate School processes this request. At that time, you will be able\nto[ log into your\nPage 3661', metadata={'page': 3660.0, 'source': './data1/doc17_Conversation Records between Students and College Management.pdf'}),
#  Document(page_content='programs.  I intend to go for the MS BAIS program, Fall 2023 for which I have applied and got the\nacceptance email.    *Does it mean I would not get the admit and I20 processing for BAIS program if\nthe Computer science application shows ADMITTED?*  Please help me here and let me know if any\nfurther information is required.   Thanks and  ~,  ~ +91 9080157223\nConversation 4264:\nConversation: 4264\nStudent Query 1: HI USF,       I have registered for the orientation. Please review my profile and let\nme know the prerequisites along with the course links.       NAME: KACHAM NIKHIL   USF ID:  ~ \nTERM OF ENTRY :FALL 2023 COURSE NAME: BAIS.       Thanks.       KACHAM NIKHIL.\nResponse 1 to the student: Hi,\xa0 Thank you for your request to do a prerequisite check.  I have\nreviewed your transcripts and resume from your application, and you have\xa0the following\nprerequisites to complete:\xa0\xa0  * Database Design-- This has to be completed before you can take', metadata={'page': 4211.0, 'source': './data1/doc17_Conversation Records between Students and College Management.pdf'}),
#  Document(page_content='of admission to this program to determine how many spaces remain. We will have an update for you\nby email and in your application portal by the end of March.       I am sure that this is not the news\nyou wanted to hear but the program is very competitive and attracts many more applicants than we\ncan accommodate.              ~   MS BAIS Academic Advisor   School of Information Systems and\nManagement     Muma College of Business      !image.png|thumbnail!      {quote}\nResponse 1 to the student: !image.png|thumbnail!\nStudent Query 2: Thank you for applying to our MS BAIS program.\xa0 At this time, it has been decided\nthat we are no longer reviewing applications for fall 2023.\xa0\xa0Our program does fill up quickly and in\norder for us to best serve each student, we have reached capacity. We understand this is not your\nfirst option, but we strongly encourage you to reapply for\xa0_spring 2024 or fall 2024_.\xa0\xa0  We are happy', metadata={'page': 336.0, 'source': './data1/doc17_Conversation Records between Students and College Management.pdf'})]

# %% [markdown]
# We can see above that from similarity search we found relevant 4 docs listed above. Now explore other retrieval methods where we can send this doc to LLM to produce the natural language response by utilizing rectrieved chunks from the semantic search.

# %%
from langchain.chat_models import ChatOpenAI
llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0.5)

# %%
## Retrieval using langChain (from langchain.chains import RetrievalQA)
qa_chain = RetrievalQA.from_chain_type(
    llm,
    retriever=vectordb.as_retriever()
)

# %%
question = "Tell me admission process in BAIS?"

# %%
result = qa_chain({"query": question})

# %%
display(Markdown(result["result"]))
# Out:
# The admission process for the MS BAIS program at USF is as follows:
#
# 1. Step 1: Submit your application, including GRE/GMAT scores, college transcripts, and other necessary details, to the USF Office of Graduate Admissions.
# 2. Step 2: The graduate admissions office will notify you of the receipt of your application, assign you a U number, review your application, and if complete, refer your application to the MS-BAIS program. This process takes approximately one month.
# 3. Step 3: The MS-BAIS program will notify you by email of the receipt of your application and ask you to provide additional information if needed.
# 4. Step 4: Once your application is reviewed, you will receive an official acceptance from the Graduate School. At that time, you will be able to log into your account and access your e-admit letter.
#
# Please note that the entire admission process may take up to two months, and admissions will close once the intake capacity for the academic year is reached. If you don't hear back within two months, it is recommended to contact the program for an update on your application status.

# %% [markdown]
# ### Database testing - Retrieval and Output using Langchain RetrievalQA and utilizing prompt template

# %%
# Build prompt
template = """Use the following pieces of context to answer the question at the end. If you don't know the answer, just say that you don't know, don't try to make up an answer. Always say "thanks for asking!" at the end of the answer. 
{context}
Question: {question}
Helpful Answer:"""
QA_CHAIN_PROMPT = PromptTemplate.from_template(template)

# %%
# Run chain
qa_chain = RetrievalQA.from_chain_type(
    llm,
    retriever=vectordb.as_retriever(),
    return_source_documents=True,
    chain_type_kwargs={"prompt": QA_CHAIN_PROMPT}
)

# %%
question = "What are the prerequisite courses in BAIS"

# %%
result = qa_chain({"query": question})

# %%
display(Markdown(result["result"]))
# Out:
# The prerequisite courses for the BAIS program are:
# 1. A course in high-level, object-oriented programming language (e.g., C#, C++, Java, and Python) or substantial programming experience.
# 2. A course in Information Systems Analysis and Design or equivalent experience.
# 3. A course in Database Systems or equivalent experience.
# 4. A course in Statistics or equivalent professional qualification or experience.
# 5. A course in economics or equivalent professional qualification or experience.
# 6. A course in financial accounting.
#
# Thanks for asking!

# %% [markdown]
# ## Overall explanation of what we are doing above is shown below in the schema

# %% [markdown]
# ![schema.png](schema.png)

# %% [markdown]
# The above diagram is a representation of a two-step process related to creating a database and querying a document using some sort of vectorized approach. Below is the overview of steps 1 and step 2 which we are doing in this project. In this report, we are more focused on step 1.
#
# **Step 1: Create Data Base (This is the main part of the project)**
#
# - **Split Type:**
#   - Various types of files, such as PDFs, TXTs, and URLs, are ingested.
#   - Preprocessing or splitting phase to extract relevant data or sections from these sources.
#
# - **Embedding Type:**
#   - The extracted data or sentences from the source files are then embedded or transformed into a numerical vector form.
#   - This might be using word embeddings or other Natural Language Processing techniques.
#
# - **Model & VectorStore:**
#   - The created vectors are then stored in a "VectorStore". This is like a database but specifically designed to handle vectors. We are using Pinecone database in this project.
#   - In case of search, the model calculates the "distance" between vectors. This would be useful for understanding the similarity between different pieces of data or to retrieve relevant information.
#   - As you can see, the vector storage system is visually represented as a container holding various vectorized data.
#
# **Step 2: Ask to the document (Here we use retrieval and LLM – OpenAI API Calls)**
#
# - **Question:**
#   - For example, a user or system can pose a question: "What is …". Through retrieval, we can get the relevant files or chunks for vector search based on the semantic search on this query.
#
# - **LLM (OpenAI- “gpt-3.5-turbo”):**
#   - The question plus the relevant doc retrieved will pass to an LLM.
#   - The LLM understands and processes the question in the context of the data passed to it and its own knowledge parameters.
#
# - **Relevance and Answers:**
#   - The LLM then determines the most relevant "splits" and comes up with the best possible answer to the question asked.
#   - It then provides an answer in natural language: Ex. "It is ...".
#
# In conclusion, the convergence of traditional database methods with advanced vector embeddings and natural language processing heralds a new era in information management and retrieval. The system we've outlined not only holds the potential to streamline data integration but also ensures more contextually relevant data extraction based on natural language queries. As the demands of information processing continue to grow, it is imperative that our systems evolve in tandem, offering solutions that are both efficient and intuitive. This study has laid the groundwork for what promises to be an exciting journey ahead in the realm of data storage and retrieval.
